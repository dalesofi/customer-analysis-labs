# %% [markdown]
# # Customer Analysis Labs (All)
#
# ## Round 2
#
# ### Install and read csv

# %%
import pandas as pd
df = pd.DataFrame(pd.read_csv("files_for_lab/csv_files/marketing_customer_analysis.csv"))
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %% [markdown]
# ### Show the dataframe shape

# %%
df.shape
# Out:
# (10910, 26)

# %% [markdown]
# ### Standartize header names
#
# 1. See column names
# 2. I can drop the Unnamed column
# 3. See the change

# %%
display(df.columns)
df1 = df.drop(labels = "Unnamed: 0", axis=1)
display(df1.columns)
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
# ...

# %% [markdown]
# 4. Have all header names on lowercase
# 5. Have all " " replaced by "_"
# 6. Add a space for the CamelCases like "EmploymentStatus"

# %%
df1.columns = df1.columns.str.lower()

# %%
df1.columns = df1.columns.str.replace("[ ]", "_", regex=True)
df1.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
df1.columns = s
## Series.str.split(pat=None, *, n=-1, expand=False, regex=None)[source]

df1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df1.columns = s
#       2 ## Series.str.split(pat=None, *, n=-1, expand=False, regex=None)[source]
#       4 df1.columns
#
# NameError: name 's' is not defined

# %%
df1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df1.columns
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ### Kinds of columns
# 3. Which columns are numerical?
# df1.value_counts('Monthly Premium Auto')
#
# - 'Customer Lifetime Value',
# - 'Effective To Date' (date)
# - 'Income',
# - 'Months Since Last Claim',
# - 'Months Since Policy Inception',
# - 'Number of Open Complaints',
# - 'Monthly Premium Auto',
# - 'Number of Policies',
# - 'Total Claim Amount'
#
#
# 4. Which columns are categorical?
#
# - 'Customer',
# - 'State',
# - 'Response',
# - 'Coverage',
# - 'Education',
# - 'EmploymentStatus',
# - 'Gender',
# - 'Location Code',
# - 'Marital Status',
# - 'Policy Type',
# - 'Policy',
# - 'Renew Offer Type',
# - 'Sales Channel'
# - 'Vehicle Class'
# - 'Vehicle Size',
# - 'Vehicle Type'
#
#
# ### Check and deal with NaN values.

# %%
print(df1.shape)
df1.info() #show the nans 
df1.isna().sum()
# Out:
# (10910, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
## I just wanna drop the small nanas for 3k nans
df1 = df1.dropna(subset=["state", "response", "months_since_last_claim", "number_of_open_complaints", "vehicle_class", "vehicle_size"])
df1.isna().sum()

### well ok I have 4k nans but i dont wanna just drop em, ill make a mask 
mask1 = (df1["vehicle_type"].isna() == True)
mask2 = (df1["vehicle_type"].isna() == False)


display(df1[mask1])
display(df1[mask2])
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 6      IW72280  California              5035.035257       No     Basic
# 7      IH64929  California              4956.247235       No     Basic
# 8      FM55990  California              5989.773931      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10893  CG69038  Washington              4817.992644       No     Basic
# 10898  SO95845  California              5807.659307       No     Basic
# 10900  VN73653      Oregon              6423.739052       No     Basic
# 10901  RY92254  Washington              4547.892543       No   Premium
# 10907  TL39050     Arizona             23893.304100       No  Extended
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# ## Datetime format
# 1. Extract the months from the dataset from the column "effective_to_date"
# 2. store in a separate column.
# 3.  filter the data to show only the information for the first quarter , ie. January, February and March.
#     Hint: If data from March does not exist, consider only January and February.

# %%
df1['month'] = pd.DatetimeIndex(df1["effective_to_date"]).month
df1.value_counts(subset = "month")
# Out:
# month
# 1    4898
# 2    4236
# Name: count, dtype: int64

# %% [markdown]
# ## BONUS:
# ### Put all the previously mentioned data transformations into a function.

# %% [markdown]
# # Lab | Customer Analysis Round 3
#
# ## Show DataFrame info.

# %%
df1.info
# Out:
# <bound method DataFrame.info of       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# ## Describe DataFrame.

# %%
df1.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             10910.000000  10910.000000          10910.000000
# mean               8018.241094  37536.284785             93.196059
# std                6885.081434  30359.195670             34.442532
# min                1898.007675      0.000000             61.000000
# 25%                4014.453113      0.000000             68.000000
# 50%                5771.147235  33813.500000             83.000000
# 75%                8992.779137  62250.750000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count             10277.000000                   10910.000000
# mean                 15.149071                      48.091934
# std                  10.080349                      27.940675
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# ### Show a plot of the total number of responses.

# %%
## Import all dependencies
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import scipy.stats as stats


# response is a categorical variable so histogram  

df1.response.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/l2/x3cc3tk1125170bw5761ztrw0000gq/T/ipykernel_8716/2574127939.py in ?()
#       7
#       8
#       9 # response is a categorical variable so histogram
#      10 df1.response.hist()
# ---> 11 df1.response.pieplot()
#      12
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'pieplot'

# %% [markdown]
# ### Show a plot of the response rate by the sales channel.
# 1. create a separate mask for the yes answers and that's the response rate
# 2. then sort by the channel indicating what % of the traffic responded

# %%
## sales_channel is also categorical, lets explore 
df1.sales_channel.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Show a plot of the response rate by the total claim amount.

# %% [markdown]
# ### Show a plot of the response rate by income.

# %% [markdown]
# # Customer Analysis - Round 4
#
# ## Step 1
# 1. Check the data types of the columns.
# 2. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
df1.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
numerics = ['int32', 'int64', 'float64']
numeric_df = df1.select_dtypes(include= numerics)
print(numeric_df)
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 6                  5035.035257   37405                    63
# ...                        ...     ...                   ...
# 10903              2771.663013   59855                    74
# 10904             19228.463620       0                   187
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
categorical = ["object"]
categorical_df = df1.select_dtypes(include= categorical)
print(categorical_df)
# Out:
#       customer       state response  coverage             education  \
# 0      DK49336     Arizona       No     Basic               College
# 1      KX64629  California       No     Basic               College
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 6      IW72280  California       No     Basic                Doctor
# ...        ...         ...      ...       ...                   ...
# 10903  SU71163     Arizona       No     Basic               College
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10906  KX53892      Oregon       No     Basic               College
# 10907  TL39050     Arizona       No  Extended              Bachelor
# 10908  WA60547  California       No   Premium               College
#
#       effective_to_date employmentstatus gender location_code marital_status  \
# ...

# %% [markdown]
# ## step 2: check normality of numerical variables
# 1. Use seaborn library to construct distribution plots for the numerical variables
#
# sns

# %%
display(numeric_df)
##for column in numeric_df:
    ##sns.displot(column, x= numeric_df.column )

#sns.displot(numeric_df, x="customer_lifetime_value")
#sns.displot(numeric_df, x="income")
#sns.displot(numeric_df, x="monthly_premium_auto")
#sns.displot(numeric_df, x="months_since_last_claim")
sns.pairplot(numeric_df)
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 6                  5035.035257   37405                    63
# ...                        ...     ...                   ...
# 10903              2771.663013   59855                    74
# 10904             19228.463620       0                   187
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %% [markdown]
# 2. Use Matplotlib to construct histograms
# import matplotlib.pyplot as plt
# import matplotlib

# %%
# we already imported the above, but apparently smtg is missing 
###import matplotlib.pyplot as plt
##import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
## axs["income"].hist(numerical_df, bins=20)

sns.distplot(numeric_df.income, bins=50)
plt.show()
##plt.hist("income")
##plt.show()
# Out:
# /var/folders/l2/x3cc3tk1125170bw5761ztrw0000gq/T/ipykernel_8716/2785066337.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numeric_df.income, bins=50)

# %% [markdown]
# 3. Do the distributions for different numerical variables look like a normal distribution
# NOOOOO

# %% [markdown]
# 4. For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

# %%
#cHECK MULTICOLINEARITY

## correlation matrix bewteen the numerical variables of the dataset

correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
# month                                        -0.006096  0.000169
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %% [markdown]
# 5. Drop one of the two features that show a high correlation between them (greater than 0.9).
#
#
# Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
# drop features highly correlated  corr > 0.95

sns.heatmap(correlation_matrix, annot=True)

plt.show()

plt.savefig("seaborn_heatmap.png", format='svg')
